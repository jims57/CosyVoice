# %%
# !rm -rf ~/.local/share/Trash/*

# %%
# !rm /root/CosyVoice/zero_shot_0.wav
# !rm /root/CosyVoice/zero_shot_1.wav
# !rm /root/CosyVoice/zero_shot_2.wav
# !rm /root/CosyVoice/zero_shot_3.wav
# !rm /root/CosyVoice/cosy_mp3_chunks/*

# !rm -rf ~/.local/share/Trash/*
# Out:
# rm: cannot remove '/root/CosyVoice/zero_shot_0.wav': No such file or directory
# rm: cannot remove '/root/CosyVoice/zero_shot_1.wav': No such file or directory
# rm: cannot remove '/root/CosyVoice/zero_shot_2.wav': No such file or directory
# rm: cannot remove '/root/CosyVoice/zero_shot_3.wav': No such file or directory

# %% [raw]
# source /root/cosy/bin/activate

# %%
#!python combine_all_wavs_into_a_single_wav.py

from IPython.display import Audio, display
import os

# audio_file_path = os.path.expanduser('~/CosyVoice/combined_audio.wav')
# audio_file_path = os.path.expanduser('~/CosyVoice/output.mp3')
# audio_file_path = os.path.expanduser('~/CosyVoice/test.wav')

audio_file_path = os.path.expanduser('/root/CosyVoice/zero_shot_0.wav')
# audio_file_path = os.path.expanduser('/root/CosyVoice/zero_shot_1.wav')
# audio_file_path = os.path.expanduser('/root/CosyVoice/zero_shot_2.wav')
# audio_file_path = os.path.expanduser('/root/CosyVoice/zero_shot_3.wav')



# Check if the file exists before trying to play it
if os.path.exists(audio_file_path):
    print(f"Playing audio from: {audio_file_path}")
    display(Audio(audio_file_path))
else:
    print(f"Error: Audio file not found at {audio_file_path}")
    print("Please ensure the file path is correct and the file exists.")

# %% [markdown]
# # Image history

# %% [markdown]
# ### (save-image)
# version="1.3.7" && server_name="cosy-tts" && image_prefix="jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker commit --pause=false "${server_name}" "${image_name}:${tag}"
#
# (push-image-only)
# version="1.3.7" && server_name="cosy-tts" && image_prefix="jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker push "${image_name}:${tag}"
#
# (save-and-push-image)
# version="1.3.7" && server_name="cosy-tts" && image_prefix="jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker commit --pause=false "${server_name}" "${image_name}:${tag}" && docker push "${image_name}:${tag}"
#
# (docker pull)
# version="1.3.7" && server_name="cosy-tts" && image_prefix="jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker pull "${image_name}:${tag}"
#
# (start-docker)
# version="1.3.7" && server_name="cosy-tts" && image_prefix="jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker rm "${server_name}" -f && docker run --gpus all -it -p 7860:7860 -p 8080:8080 -p 9000:9000 -p 9001:9001 -p 9002:9002 -p 9003:9003 --shm-size=16g -w /root/CosyVoice --name "${server_name}" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh && rm -f pretrained_models/CosyVoice2-0.5B/flow.decoder.estimator.fp16.mygpu.plan && cd ~/CosyVoice && /root/CosyVoice/cosy_vllm/bin/python cosy-api.py --port 9001; /bin/bash"
#
#
# v1.3.7:
#     * fix bug for dada sound of combined pcm with headers
# v1.3.6:
#     * prepend header info(startTimeId and messageId) for pcm
# v1.3.5:
#     * add speakerId-11(吴明)
# v1.3.4:
#     * add additional 9 speakers
#     * add empty chunk after all chunks are sent
# v1.3.3:
#     * delete flow.decoder.estimator.fp16.mygpu.plan
#     * add HEAD for ALB health check, and change ws name to /tts from /cosy-tts
# v1.3.1:
#     * add timeout to 30 mins for ws connection
#     * add --port parameter for cosy-api.py
# v1.3:
#     * install vllm and make cosy-api.py work
# v1.2.1:
#     * 【important】demo.py can run normally
#     * 【important】download models successfully
# v1.2:
#     * use nvcr.io/nvidia/pytorch:24.04-py3 image to use python 3.10.12
# v1.1.1:
#     * install ttsfrd
#     * upload cosy-api.py
# v1.1:
#     * install CosyVoice and Jupyter

# %% [markdown]
# # run multi docker containers

# %% [markdown]
# docker rm "cosy-tts-1" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="0-3" -p 9000:9000 -p 9001:9001 --shm-size=3g -w /root/CosyVoice --name "cosy-tts-1" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh; /bin/bash"
#
# version="1.3.7"
# server_name="cosy-tts"
# image_prefix="jims57"
# image_name="${image_prefix}/cosy-tts"
# tag="v${version}"
#
#
# ==== (auto starting api) ====
# docker rm "cosy-tts-1" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="0-3" -p 9000:9000 -p 9001:9001 --shm-size=3g -w /root/CosyVoice --name "cosy-tts-1" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh && rm -f pretrained_models/CosyVoice2-0.5B/flow.decoder.estimator.fp16.mygpu.plan && cd ~/CosyVoice && /root/CosyVoice/cosy_vllm/bin/python cosy-api.py --port 9001; /bin/bash"
#
# docker rm "cosy-tts-2" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="4-7" -p 9002:9002 --shm-size=3g -w /root/CosyVoice --name "cosy-tts-2" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh && rm -f pretrained_models/CosyVoice2-0.5B/flow.decoder.estimator.fp16.mygpu.plan && cd ~/CosyVoice && /root/CosyVoice/cosy_vllm/bin/python cosy-api.py --port 9002; /bin/bash"
#
# docker rm "cosy-tts-3" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="8-11" -p 9003:9003 --shm-size=3g -w /root/CosyVoice --name "cosy-tts-3" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh && rm -f pretrained_models/CosyVoice2-0.5B/flow.decoder.estimator.fp16.mygpu.plan && cd ~/CosyVoice && /root/CosyVoice/cosy_vllm/bin/python cosy-api.py --port 9003; /bin/bash"
#
# docker rm "cosy-tts-4" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="12-15" -p 9004:9004 --shm-size=3g -w /root/CosyVoice --name "cosy-tts-4" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh && rm -f pretrained_models/CosyVoice2-0.5B/flow.decoder.estimator.fp16.mygpu.plan && cd ~/CosyVoice && /root/CosyVoice/cosy_vllm/bin/python cosy-api.py --port 9004; /bin/bash"
#
#
# ==== (run with auto starting api)
# docker rm "cosy-tts-1" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="0-3" -p 9000:9000 -p 9001:9001 --shm-size=3g -w /root/CosyVoice --name "cosy-tts-1" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh; /bin/bash"
#
# docker rm "cosy-tts-2" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="4-7" -p 9002:9002 --shm-size=3g -w /root/CosyVoice --name "cosy-tts-2" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh; /bin/bash"
#
# docker rm "cosy-tts-3" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="8-11" -p 9003:9003 --shm-size=3g -w /root/CosyVoice --name "cosy-tts-3" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh; /bin/bash"
#
# docker rm "cosy-tts-4" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="12-15" -p 9004:9004 --shm-size=3g -w /root/CosyVoice --name "cosy-tts-4" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh; /bin/bash"

# %% [markdown]
# # Other notes

# %% [raw]
# source /root/cosy/bin/activate
#
# source /root/CosyVoice/cosy_vllm/bin/activate
#
# find ~ -type f -name "activate" -path "*/bin/activate" 2>/dev/null
#
# cd ~/CosyVoice && /root/cosy/bin/python demo.py
#
# rm pretrained_models/CosyVoice2-0.5B/flow.decoder.estimator.fp16.mygpu.plan
#
# (run cosy api)
# cd ~/CosyVoice && rm pretrained_models/CosyVoice2-0.5B/flow.decoder.estimator.fp16.mygpu.plan &&/root/CosyVoice/cosy_vllm/bin/python cosy-api.py --port 9001
# cd ~/CosyVoice &&/root/CosyVoice/cosy_vllm/bin/python cosy-api.py --port 9001
#
# cd ~/CosyVoice && rm pretrained_models/CosyVoice2-0.5B/flow.decoder.estimator.fp16.mygpu.plan &&/root/CosyVoice/cosy_vllm/bin/python cosy-api.py --port 9002
# cd ~/CosyVoice &&/root/CosyVoice/cosy_vllm/bin/python cosy-api.py --port 9002
#
# cd ~/CosyVoice && rm pretrained_models/CosyVoice2-0.5B/flow.decoder.estimator.fp16.mygpu.plan &&/root/CosyVoice/cosy_vllm/bin/python cosy-api.py --port 9003
# cd ~/CosyVoice &&/root/CosyVoice/cosy_vllm/bin/python cosy-api.py --port 9003
#
# cd ~/CosyVoice && /root/CosyVoice/cosy_vllm/bin/python cosy-api.py

# %% [markdown]
# # verify pcm header

# %%
import struct

# 将十六进制转换回数字
header_hex = "00000198 112CDE08 0001E240"
header_bytes = bytes.fromhex(header_hex)

# 解析（大端序格式）
parsed_start_time_id = struct.unpack('>Q', header_bytes[:8])[0]
parsed_message_id = struct.unpack('>I', header_bytes[8:12])[0]

print(f"Parsed startTimeId: {parsed_start_time_id}")  # 应该是 1752634739864
print(f"Parsed messageId: {parsed_message_id}")      # 应该是 12345678
# Out:
# Parsed startTimeId: 1752634809864
# Parsed messageId: 123456
